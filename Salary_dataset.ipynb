# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "C:\\Users\\Asus\\Downloads\\Salary_dataset.csv"

# %%
data = pd.read_csv(path)

# %%
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
data2 = data["Salary"]

# %%
data2
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
data1 = data.drop("Salary",axis = 1)

# %%
data1
# Out:
#     Unnamed: 0  YearsExperience
# 0            0              1.2
# 1            1              1.4
# 2            2              1.6
# 3            3              2.1
# 4            4              2.3
# 5            5              3.0
# 6            6              3.1
# 7            7              3.3
# 8            8              3.3
# 9            9              3.8
# 10          10              4.0
# 11          11              4.1
# 12          12              4.1
# 13          13              4.2
# 14          14              4.6
# 15          15              5.0
# 16          16              5.2
# 17          17              5.4
# 18          18              6.0
# 19          19              6.1
# 20          20              6.9
# 21          21              7.2
# 22          22              8.0
# 23          23              8.3
# 24          24              8.8
# 25          25              9.1
# 26          26              9.6
# 27          27              9.7
# 28          28             10.4
# 29          29             10.6

# %%
plt.scatter(data["YearsExperience"], data["Salary"])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
clt = LinearRegression()

# %%
clt.fit(data1,data2)
# Out:
# LinearRegression()

# %%
clt.predict(data1)
# Out:
# array([ 36964.0644892 ,  38666.70434015,  40369.3441911 ,  45350.28147982,
#         47052.92133077,  54219.39024467,  54829.26428303,  56531.90413398,
#         56049.01235976,  61029.94964848,  62732.58949943,  63342.46353779,
#         62859.57176356,  63469.44580193,  67357.61727806,  71245.78875419,
#         72948.42860514,  74651.06845609,  80724.7715574 ,  81334.64559576,
#         89593.88032225,  92389.28598579, 100648.52071227, 103443.92637581,
#        108424.86366453, 111220.26932807, 116201.20661679, 116811.08065515,
#        123977.54956905, 125680.18942   ])

# %%
x = clt.coef_

# %%
x
# Out:
# array([ -482.89177423, 10927.65812589])

# %%
b = clt.intercept_

# %%
b
# Out:
# np.float64(23850.874738130275)

# %%
data1*x + b
# Out:
#       Unnamed: 0  YearsExperience
# 0   23850.874738     36964.064489
# 1   23367.982964     39149.596114
# 2   22885.091190     41335.127740
# 3   22402.199415     46798.956802
# 4   21919.307641     48984.488428
# 5   21436.415867     56633.849116
# 6   20953.524093     57726.614928
# 7   20470.632319     59912.146554
# 8   19987.740544     59912.146554
# 9   19504.848770     65375.975617
# 10  19021.956996     67561.507242
# 11  18539.065222     68654.273054
# 12  18056.173447     68654.273054
# 13  17573.281673     69747.038867
# 14  17090.389899     74118.102117
# 15  16607.498125     78489.165368
# 16  16124.606351     80674.696993
# 17  15641.714576     82860.228618
# 18  15158.822802     89416.823493
# 19  14675.931028     90509.589306
# 20  14193.039254     99251.715807
# 21  13710.147479    102530.013245
# 22  13227.255705    111272.139745
# 23  12744.363931    114550.437183
# 24  12261.472157    120014.266246
# 25  11778.580382    123292.563684
# 26  11295.688608    128756.392747
# 27  10812.796834    129849.158559
# 28  10329.905060    137498.519247
# 29   9847.013286    139684.050873
